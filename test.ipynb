# %%
A = []

# %%
A.append([2,3])
A.append([4,1])

# %%
A[0][1]
# Out:
# 3

# %%
A
# Out:
# [[2, 3], [4, 1]]

# %%
A.sort()
A
# Out:
# [[2, 3], [4, 1]]

# %%
str = ["banana", "apple", "cherry"] 
str.sort()
str
# Out:
# ['apple', 'banana', 'cherry']

# %%
str = "abababa"
sorted_str = sorted(str)

# %%
sorted_str
# Out:
# ['a', 'a', 'a', 'a', 'b', 'b', 'b']

# %%
m = [1,3,2,-1,4,1,1,2,3,3,4] 
n = set(m)
n
# Out:
# {-1, 1, 2, 3, 4}

# %%
h = list(dict.fromkeys(m))

# %%
h
# Out:
# [1, 3, 2, -1, 4]

# %%
dict.fromkeys(m,0)
# Out:
# {1: 0, 3: 0, 2: 0, -1: 0, 4: 0}

# %%
from collections import defaultdict
mydict = defaultdict(int)

mydict["key1"] += 1

# %%
mydict["key4"]
# Out:
# 0

# %%
mytuple = tuple(m)

# %%
mytuple = ("123",1,2,3,"a")

# %%
mytuple.replace("1","0")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 mytuple.replace("1","0")
#
# AttributeError: 'tuple' object has no attribute 'replace'

# %%
array = dict.fromkeys(m,99)
complicated_tuple = (tuple(array), tuple(array), tuple(array))

# %%
complicated_tuple
# Out:
# ((1, 3, 2, -1, 4), (1, 3, 2, -1, 4), (1, 3, 2, -1, 4))

# %%
mycomplicated_dict = {complicated_tuple: "super complicated"}

# %%
mycomplicated_dict
# Out:
# {((1, 3, 2, -1, 4), (1, 3, 2, -1, 4), (1, 3, 2, -1, 4)): 'super complicated'}

# %%
array
# Out:
# {1: 99, 3: 99, 2: 99, -1: 99, 4: 99}

# %%
list(mycomplicated_dict.keys())
# Out:
# [((1, 3, 2, -1, 4), (1, 3, 2, -1, 4), (1, 3, 2, -1, 4))]

# %%
str = 'asdasdas'

for i in str:
    print(i)
# Out:
# a
# s
# d
# a
# s
# d
# a
# s

# %%
dict = {"key1": "value1", "key2": "value2", "key3": "value3"} 

print(list(dict.values()))
# Out:
# ['value1', 'value2', 'value3']
